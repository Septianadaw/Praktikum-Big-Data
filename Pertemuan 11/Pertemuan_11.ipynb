# %%
# 1. Advanced CRUD Operations
# Exercise 1: Use bulk_write to insert, update, and delete multiple documents simultaneously.
# Task 1: Insert a dataset of courses where each course has multiple student enrollments, then display the data.

from pymongo import MongoClient, InsertOne, UpdateOne, DeleteOne
import random

# Koneksi ke MongoDB
client = MongoClient('mongodb://localhost:27017/')
db = client['university_db']
courses_collection = db['courses']

# Hapus data lama agar tidak duplikat
courses_collection.delete_many({})

# Task 1: INSERT DATASET
# Bulk insert (menambahkan 50 dokumen baru dengan data acak)
departments = ['Mathematics', 'Computer Science', 'Physics', 'History', 'Economics']
operations = []

for i in range(1, 51):
    course_name = f"Course {i}"
    enrollments = random.randint(10, 100)
    dept = random.choice(departments)
    operations.append(
        InsertOne({
            'course': course_name,
            'enrollments': enrollments,
            'department': dept
        })
    )

# Eksekusi operasi insert secara bulk
result = courses_collection.bulk_write(operations)
print(f"{len(operations)} courses inserted successfully.\n")

# Tampilkan seluruh dokumen yang telah dimasukkan
print("=== Data Setelah INSERT ===")
for doc in courses_collection.find():
    print(doc)


# Task 2: UPDATE beberapa dokumen
# Misalnya kita ingin menaikkan jumlah enrollments untuk semua mata kuliah di Computer Science
update_operations = [
    UpdateOne(
        {'department': 'Computer Science'},          # filter
        {'$inc': {'enrollments': 10}},               # action (tambah 10)
        upsert=False
    ),
    UpdateOne(
        {'course': 'Course 5'},                      # contoh update satu course tertentu
        {'$set': {'department': 'Data Science'}},    # ubah departemen jadi Data Science
        upsert=False
    )
]

courses_collection.bulk_write(update_operations)

print("\n=== Data Setelah UPDATE ===")
for doc in courses_collection.find({'department': {'$in': ['Computer Science', 'Data Science']}}):
    print(doc)


# Task 3: DELETE beberapa dokumen
# Misalnya kita hapus course dengan enrollments < 20
delete_operations = [
    DeleteOne({'enrollments': {'$lt': 20}})  # hapus satu dokumen dengan syarat tertentu
]

courses_collection.bulk_write(delete_operations)

print("\n=== Data Setelah DELETE (hapus enrollments < 20) ===")
for doc in courses_collection.find():
    print(doc)
# Out:
# 50 courses inserted successfully.
#
# === Data Setelah INSERT ===
# {'_id': ObjectId('690c1002719d516ba19eb070'), 'course': 'Course 1', 'enrollments': 50, 'department': 'History'}
# {'_id': ObjectId('690c1002719d516ba19eb071'), 'course': 'Course 2', 'enrollments': 16, 'department': 'Computer Science'}
# {'_id': ObjectId('690c1002719d516ba19eb072'), 'course': 'Course 3', 'enrollments': 47, 'department': 'History'}
# {'_id': ObjectId('690c1002719d516ba19eb073'), 'course': 'Course 4', 'enrollments': 23, 'department': 'Mathematics'}
# {'_id': ObjectId('690c1002719d516ba19eb074'), 'course': 'Course 5', 'enrollments': 80, 'department': 'Mathematics'}
# {'_id': ObjectId('690c1002719d516ba19eb075'), 'course': 'Course 6', 'enrollments': 39, 'department': 'Physics'}
# {'_id': ObjectId('690c1002719d516ba19eb076'), 'course': 'Course 7', 'enrollments': 33, 'department': 'Computer Science'}
# {'_id': ObjectId('690c1002719d516ba19eb077'), 'course': 'Course 8', 'enrollments': 25, 'department': 'Economics'}
# {'_id': ObjectId('690c1002719d516ba19eb078'), 'course': 'Course 9', 'enrollments': 51, 'department': 'Economics'}
# {'_id': ObjectId('690c1002719d516ba19eb079'), 'course': 'Course 10', 'enrollments': 83, 'department': 'Mathematics'}
# {'_id': ObjectId('690c1002719d516ba19eb07a'), 'course': 'Course 11', 'enrollments': 29, 'department': 'Physics'}
# {'_id': ObjectId('690c1002719d516ba19eb07b'), 'course': 'Course 12', 'enrollments': 93, 'department': 'Mathematics'}
# {'_id': ObjectId('690c1002719d516ba19eb07c'), 'course': 'Course 13', 'enrollments': 54, 'department': 'Computer Science'}
# {'_id': ObjectId('690c1002719d516ba19eb07d'), 'course': 'Course 14', 'enrollments': 74, 'department': 'Mathematics'}
# {'_id': ObjectId('690c1002719d516ba19eb07e'), 'course': 'Course 15', 'enrollments': 29, 'department': 'Mathematics'}
# {'_id': ObjectId('690c1002719d516ba19eb07f'), 'course': 'Course 16', 'enrollments': 29, 'department': 'Physics'}
# {'_id': ObjectId('690c1002719d516ba19eb080'), 'course': 'Course 17', 'enrollments': 12, 'department': 'Physics'}
# {'_id': ObjectId('690c1002719d516ba19eb081'), 'course': 'Course 18', 'enrollments': 85, 'department': 'Physics'}
# {'_id': ObjectId('690c1002719d516ba19eb082'), 'course': 'Course 19', 'enrollments': 65, 'department': 'Mathematics'}
# {'_id': ObjectId('690c1002719d516ba19eb083'), 'course': 'Course 20', 'enrollments': 84, 'department': 'History'}
# {'_id': ObjectId('690c1002719d516ba19e
 'department': 'Mathematics'}
# {'_id': ObjectId('690c1002719d516ba19eb095'), 'course': 'Course 38', 'enrollments': 30, 'department': 'Economics'}
# {'_id': ObjectId('690c1002719d516ba19eb096'), 'course': 'Course 39', 'enrollments': 95, 'department': 'History'}
# {'_id': ObjectId('690c1002719d516ba19eb097'), 'course': 'Course 40', 'enrollments': 23, 'department': 'History'}
# {'_id': ObjectId('690c1002719d516ba19eb098'), 'course': 'Course 41', 'enrollments': 87, 'department': 'History'}
# {'_id': ObjectId('690c1002719d516ba19eb099'), 'course': 'Course 42', 'enrollments': 31, 'department': 'Physics'}
# {'_id': ObjectId('690c1002719d516ba19eb09a'), 'course': 'Course 43', 'enrollments': 94, 'department': 'Physics'}
# {'_id': ObjectId('690c1002719d516ba19eb09b'), 'course': 'Course 44', 'enrollments': 72, 'department': 'Physics'}
# {'_id': ObjectId('690c1002719d516ba19eb09c'), 'course': 'Course 45', 'enrollments': 81, 'department': 'Computer Science'}
# {'_id': ObjectId('690c1002719d516ba19eb09e'), 'course': 'Course 47', 'enrollments': 43, 'department': 'Economics'}
# {'_id': ObjectId('690c1002719d516ba19eb09f'), 'course': 'Course 48', 'enrollments': 63, 'department': 'History'}
# {'_id': ObjectId('690c1002719d516ba19eb0a1'), 'course': 'Course 50', 'enrollments': 56, 'department': 'Mathematics'}

# %%
# Mengambil data course yang berasal dari jurusan Computer Science atau Mathematics
print("Courses in 'Computer Science' or 'Mathematics' departments: ")
for course in courses_collection.find({'department': {'$in': ['Computer Science', 'Mathematics']}}):
    print(course)
# Out:
# Courses in 'Computer Science' or 'Mathematics' departments:
# {'_id': ObjectId('690c1002719d516ba19eb071'), 'course': 'Course 2', 'enrollments': 26, 'department': 'Computer Science'}
# {'_id': ObjectId('690c1002719d516ba19eb073'), 'course': 'Course 4', 'enrollments': 23, 'department': 'Mathematics'}
# {'_id': ObjectId('690c1002719d516ba19eb076'), 'course': 'Course 7', 'enrollments': 33, 'department': 'Computer Science'}
# {'_id': ObjectId('690c1002719d516ba19eb079'), 'course': 'Course 10', 'enrollments': 83, 'department': 'Mathematics'}
# {'_id': ObjectId('690c1002719d516ba19eb07b'), 'course': 'Course 12', 'enrollments': 93, 'department': 'Mathematics'}
# {'_id': ObjectId('690c1002719d516ba19eb07c'), 'course': 'Course 13', 'enrollments': 54, 'department': 'Computer Science'}
# {'_id': ObjectId('690c1002719d516ba19eb07d'), 'course': 'Course 14', 'enrollments': 74, 'department': 'Mathematics'}
# {'_id': ObjectId('690c1002719d516ba19eb07e'), 'course': 'Course 15', 'enrollments': 29, 'department': 'Mathematics'}
# {'_id': ObjectId('690c1002719d516ba19eb082'), 'course': 'Course 19', 'enrollments': 65, 'department': 'Mathematics'}
# {'_id': ObjectId('690c1002719d516ba19eb087'), 'course': 'Course 24', 'enrollments': 60, 'department': 'Mathematics'}
# {'_id': ObjectId('690c1002719d516ba19eb08b'), 'course': 'Course 28', 'enrollments': 99, 'department': 'Computer Science'}
# {'_id': ObjectId('690c1002719d516ba19eb08f'), 'course': 'Course 32', 'enrollments': 95, 'department': 'Computer Science'}
# {'_id': ObjectId('690c1002719d516ba19eb090'), 'course': 'Course 33', 'enrollments': 46, 'department': 'Mathematics'}
# {'_id': ObjectId('690c1002719d516ba19eb094'), 'course': 'Course 37', 'enrollments': 81, 'department': 'Mathematics'}
# {'_id': ObjectId('690c1002719d516ba19eb09c'), 'course': 'Course 45', 'enrollments': 81, 'department': 'Computer Science'}
# {'_id': ObjectId('690c1002719d516ba19eb09d'), 'course': 'Course 46', 'enrollments': 11, 'department': 'Mathematics'}
# {'_id': ObjectId('690c1002719d516ba19eb0a1'), 'course': 'Course 50', 'enrollments': 56, 'department': 'Mathematics'}

# %%
# 2. Complex Filtering and Querying
# Exercise 2: Filter courses with enrollments over 20 students.
# Task 2: Retrieve and display courses only from the 'Computer Science' or 'Mathematics' departments.

# Menampilkan course (mata kuliah) yang memiliki jumlah enrollments (mahasiswa terdaftar) lebih dari 20
print("Courses with enrollments greater than 20: ")
for course in courses_collection.find({'enrollments': {'$gt': 20}}):
    print(course)

# Menampilkan course (mata kuliah) yang berasal dari departemen 'Computer Science' atau 'Mathematics'
print("Courses in 'Computer Science' or 'Mathematics' departments: ")
for course in courses_collection.find({'department': {'$in': ['Computer Science', 'Mathematics']}}):
    print(course)

# %%
# 3. Aggregation Framework for Data Analysis
# Exercise 3: Use aggregation to find the average enrollment per department.
# Task 3: Create an aggregation pipeline that finds the maximum enrollment for each department.

# Menghitung RATA-RATA (average) enrollments tiap department
# Gunakan $group untuk mengelompokkan berdasarkan department
pipeline = [
    {'$group': {'_id': '$department', 'average_enrollment': {'$avg': '$enrollments'}}} # kelompokkan berdasarkan nama department dan hitung rata-rata enrollments
]

print("Average Enrollment per Department: ")
for result in courses_collection.aggregate(pipeline):
    print(result)
# Out:
# Average Enrollment per Department:
# {'_id': 'Mathematics', 'average_enrollment': 56.45454545454545}
# {'_id': 'Computer Science', 'average_enrollment': 64.66666666666667}
# {'_id': 'Data Science', 'average_enrollment': 80.0}
# {'_id': 'Physics', 'average_enrollment': 57.1}
# {'_id': 'Economics', 'average_enrollment': 41.5}
# {'_id': 'History', 'average_enrollment': 53.86666666666667}

# %%
# Mencari NILAI MAKSIMUM enrollments tiap department
# Gunakan $group dengan operator $max
pipeline = [
    {'$group': {'_id': '$department', 'max_enrollment': {'$max': '$enrollments'}}} #  kelompokkan berdasarkan department dan cari nilai enrollments tertinggi
]

print("Maximum Enrollment per Department: ")
for result in courses_collection.aggregate(pipeline):
    print(result)
# Out:
# Maximum Enrollment per Department:
# {'_id': 'Mathematics', 'max_enrollment': 93}
# {'_id': 'Computer Science', 'max_enrollment': 99}
# {'_id': 'Data Science', 'max_enrollment': 80}
# {'_id': 'Physics', 'max_enrollment': 94}
# {'_id': 'Economics', 'max_enrollment': 80}
# {'_id': 'History', 'max_enrollment': 95}

# %%
# 4. Data Transformation using projectandaddFields
# Exercise 4: Use $project to rename and only show fields: course_name, department_name, and enrollments.
# Task 4: Use $addFields to create a new field enrollment_category where enrollments > 20 are 'high' and others 'low'.

# Gunakan $project untuk memilih dan mengganti nama field
pipeline_project = [
    {'$project': {'course_name': '$course', 'department_name': '$department', 'enrollments': 1}}
]

print("rojection: Renaming and Selecting Fields: ")
for result in courses_collection.aggregate(pipeline_project):
    print(result)
# Out:
# rojection: Renaming and Selecting Fields:
# {'_id': ObjectId('690c1002719d516ba19eb070'), 'enrollments': 50, 'course_name': 'Course 1', 'department_name': 'History'}
# {'_id': ObjectId('690c1002719d516ba19eb071'), 'enrollments': 26, 'course_name': 'Course 2', 'department_name': 'Computer Science'}
# {'_id': ObjectId('690c1002719d516ba19eb072'), 'enrollments': 47, 'course_name': 'Course 3', 'department_name': 'History'}
# {'_id': ObjectId('690c1002719d516ba19eb073'), 'enrollments': 23, 'course_name': 'Course 4', 'department_name': 'Mathematics'}
# {'_id': ObjectId('690c1002719d516ba19eb074'), 'enrollments': 80, 'course_name': 'Course 5', 'department_name': 'Data Science'}
# {'_id': ObjectId('690c1002719d516ba19eb075'), 'enrollments': 39, 'course_name': 'Course 6', 'department_name': 'Physics'}
# {'_id': ObjectId('690c1002719d516ba19eb076'), 'enrollments': 33, 'course_name': 'Course 7', 'department_name': 'Computer Science'}
# {'_id': ObjectId('690c1002719d516ba19eb077'), 'enrollments': 25, 'course_name': 'Course 8', 'department_name': 'Economics'}
# {'_id': ObjectId('690c1002719d516ba19eb078'), 'enrollments': 51, 'course_name': 'Course 9', 'department_name': 'Economics'}
# {'_id': ObjectId('690c1002719d516ba19eb079'), 'enrollments': 83, 'course_name': 'Course 10', 'department_name': 'Mathematics'}
# {'_id': ObjectId('690c1002719d516ba19eb07a'), 'enrollments': 29, 'course_name': 'Course 11', 'department_name': 'Physics'}
# {'_id': ObjectId('690c1002719d516ba19eb07b'), 'enrollments': 93, 'course_name': 'Course 12', 'department_name': 'Mathematics'}
# {'_id': ObjectId('690c1002719d516ba19eb07c'), 'enrollments': 54, 'course_name': 'Course 13', 'department_name': 'Computer Science'}
# {'_id': ObjectId('690c1002719d516ba19eb07d'), 'enrollments': 74, 'course_name': 'Course 14', 'department_name': 'Mathematics'}
# {'_id': ObjectId('690c1002719d516ba19eb07e'), 'enrollments': 29, 'course_name': 'Course 15', 'department_name': 'Mathematics'}
# {'_id': ObjectId('690c1002719d516ba19eb07f'), 'enrollments': 29, 'course_name': 'Course 16', 'department_name': 'Physics'}
# {'_id': ObjectId('690c1002719d516ba19eb081'), 'enrollments': 85, 'course_name': 'Course 18', 'department_name': 'Physics'}
# {'_id': ObjectId('690c1002719d516ba19eb082'), 'enrollments': 65, 'course_name': 'Course 19', 'department_name': 'Mathematics'}
# {'_id': ObjectId('690c1002719d516ba19eb083'), 'enrollments': 84, 'course_name': 'Course 20', 'department_name': 'History'}
# {'_id': ObjectId('690c1002719d516ba19eb084'), 'enrollments': 30, 'course_name': 'Course 21', 'department_name': 'Physics'}
# {'_id': ObjectId('690c1002719d516ba19eb085'), 'enrollments': 84, 'course_name': 'Course 22', 'department_name': 'Physics'}
# {'_id': ObjectId('690c1002719d516ba19eb086'), 'enrollments': 50, 'course_name': 'Course 23', 'department_name': 'History'}
# {'_id': ObjectId('690c1002719d516ba19eb087'), 'enrollments': 60, 'course_name': 'Course 24', 'department_name': 'Mathematics'}
# {'_id': ObjectId('690c1002719d516ba19eb088'), 'enrollments': 47, 'course_name': 'Course 25', 'department_name': 'History'}
# {'_id': ObjectId('690c1002719d516ba19eb089'), 'enrollments': 78, 'course_name': 'Course 26', 'department_name': 'Physics'}
# {'_id': ObjectId('690c1002719d516ba19eb08a'), 'enrollments': 35, 'course_name': 'Course 27', 'department_name': 'History'}
# {'_id': ObjectId('690c1002719d516ba19eb08b'), 'enrollments': 99, 'course_name': 'Course 28', 'department_name': 'Computer Science'}
# {'_id': ObjectId('690c1002719d516ba19eb08c'), 'enrollments': 92, 'course_name': 'Course 29', 'department_name': 'History'}
# {'_id': ObjectId('690c1002719d516ba19eb08d'), 'enrollments': 20, 'course_name': 'Course 30', 'department_name': 'Economics'}
# {'_id': ObjectId('690c1002719d516ba19eb08e'), 'enrollments': 21, 'course_name': 'Course 31', 'department_name': 'History'}
# {'_id': ObjectId('690c1002719d516ba19eb08f'), 'enrollments': 95, 'course_name': 'Course 32', 'department_name': 'Computer Science'}
# {'_id': ObjectId('690c1002719d516ba19eb090'), 'enrollments': 46, 'course_name': 'Course 33', 'department_name': 'Mathematics'}
# {'_id': ObjectId('690c1002719d516ba19eb091'), 'enrollments': 40, 'course_name': 'Course 34', 'department_name': 'History'}
# {'_id': ObjectId('690c1002719d516ba19eb092'), 'enrollments': 55, 'course_name': 'Course 35', 'department_name': 'History'}
# {'_id': ObjectId('690c1002719d516ba19eb093'), 'enrollments': 80, 'course_name': 'Course 36', 'department_name': 'Economics'}
# {'_id': ObjectId('690c1002719d516ba19eb094'), 'enrollments': 81, 'course_name': 'Course 37', 'department_name': 'Mathematics'}
# {'_id': ObjectId('690c1002719d516ba19eb095'), 'enrollments': 30, 'course_name': 'Course 38', 'department_name': 'Economics'}
# {'_id': ObjectId('690c1002719d516ba19eb096'), 'enrollments': 95, 'course_name': 'Course 39', 'department_name': 'History'}
# {'_id': ObjectId('690c1002719d516ba19eb097'), 'enrollments': 23, 'course_name': 'Course 40', 'department_name': 'History'}
# {'_id': ObjectId('690c1002719d516ba19eb098'), 'enrollments': 87, 'course_name': 'Course 41', 'department_name': 'History'}
# {'_id': ObjectId('690c1002719d516ba19eb099'), 'enrollments': 31, 'course_name': 'Course 42', 'department_name': 'Physics'}
# {'_id': ObjectId('690c1002719d516ba19eb09a'), 'enrollments': 94, 'course_name': 'Course 43', 'department_name': 'Physics'}
# {'_id': ObjectId('690c1002719d516ba19eb09b'), 'enrollments': 72, 'course_name': 'Course 44', 'department_name': 'Physics'}
# {'_id': ObjectId('690c1002719d516ba19eb09c'), 'enrollments': 81, 'course_name': 'Course 45', 'department_name': 'Computer Science'}
# {'_id': ObjectId('690c1002719d516ba19eb09d'), 'enrollments': 11, 'course_name': 'Course 46', 'department_name': 'Mathematics'}
# {'_id': ObjectId('690c1002719d516ba19eb09e'), 'enrollments': 43, 'course_name': 'Course 47', 'department_name': 'Economics'}
# {'_id': ObjectId('690c1002719d516ba19eb09f'), 'enrollments': 63, 'course_name': 'Course 48', 'department_name': 'History'}
# {'_id': ObjectId('690c1002719d516ba19eb0a0'), 'enrollments': 19, 'course_name': 'Course 49', 'department_name': 'History'}
# {'_id': ObjectId('690c1002719d516ba19eb0a1'), 'enrollments': 56, 'course_name': 'Course 50', 'department_name': 'Mathematics'}

# %%
#  Gunakan $addFields untuk menambah field baru berdasarkan kondisi
# Jika enrollments > 20 maka 'high', jika tidak maka 'low'
pipeline_addFields = [
    {'$addFields': {'enrollment_category': {'$cond': {'if': {'$gt': ['$enrollments', 20]}, 'then': 'high', 'else': 'low'}}}}
]

print("Adding Field: enrollment_category (high/low): ")
for result in courses_collection.aggregate(pipeline_addFields):
    print(result)
# Out:
# Adding Field: enrollment_category (high/low):
# {'_id': ObjectId('690c1002719d516ba19eb070'), 'course': 'Course 1', 'enrollments': 50, 'department': 'History', 'enrollment_category': 'high'}
# {'_id': ObjectId('690c1002719d516ba19eb071'), 'course': 'Course 2', 'enrollments': 26, 'department': 'Computer Science', 'enrollment_category': 'high'}
# {'_id': ObjectId('690c1002719d516ba19eb072'), 'course': 'Course 3', 'enrollments': 47, 'department': 'History', 'enrollment_category': 'high'}
# {'_id': ObjectId('690c1002719d516ba19eb073'), 'course': 'Course 4', 'enrollments': 23, 'department': 'Mathematics', 'enrollment_category': 'high'}
# {'_id': ObjectId('690c1002719d516ba19eb074'), 'course': 'Course 5', 'enrollments': 80, 'department': 'Data Science', 'enrollment_category': 'high'}
# {'_id': ObjectId('690c1002719d516ba19eb075'), 'course': 'Course 6', 'enrollments': 39, 'department': 'Physics', 'enrollment_category': 'high'}
# {'_id': ObjectId('690c1002719d516ba19eb076'), 'course': 'Course 7', 'enrollments': 33, 'department': 'Computer Science', 'enrollment_category': 'high'}
# {'_id': ObjectId('690c1002719d516ba19eb077'), 'course': 'Course 8', 'enrollments': 25, 'department': 'Economics', 'enrollment_category': 'high'}
# {'_id': ObjectId('690c1002719d516ba19eb078'), 'course': 'Course 9', 'enrollments': 51, 'department': 'Economics', 'enrollment_category': 'high'}
# {'_id': ObjectId('690c1002719d516ba19eb079'), 'course': 'Course 10', 'enrollments': 83, 'department': 'Mathematics', 'enrollment_category': 'high'}
# {'_id': ObjectId('690c1002719d516ba19eb07a'), 'course': 'Course 11', 'enrollments': 29, 'department': 'Physics', 'enrollment_category': 'high'}
# {'_id': ObjectId('690c1002719d516ba19eb07b'), 'course': 'Course 12', 'enrollments': 93, 'department': 'Mathematics', 'enrollment_category': 'high'}
# {'_id': ObjectId('690c1002719d516ba19eb07c'), 'course': 'Course 13', 'enrollments': 54, 'department': 'Computer Science', 'enrollment_category': 'high'}
# {'_id': ObjectId('690c1002719d516ba19eb07d'), 'course': 'Course 14', 'enrollments': 74, 'department': 'Mathematics', 'enrollment_category': 'high'}
# {'_id': ObjectId('690c1002719d516ba19eb07e'), 'course': 'Course 15', 'enrollments': 29, 'department': 'Mathematics', 'enrollment_category': 'high'}
# {'_id': ObjectId('690c1002719d516ba19eb07f'), 'course': 'Course 16', 'enrollments': 29, 'department': 'Physics', 'enrollment_category': 'high'}
# {'_id': ObjectId('690c1002719d516ba19eb081'), 'course': 'Course 18', 'enrollments': 85, 'department': 'Physics', 'enrollment_category': 'high'}
# {'_id': ObjectId('690c1002719d516ba19eb082'), 'course': 'Course 19', 'enrollments': 65, 'department': 'Mathematics', 'enrollment_category': 'high'}
# {'_id': ObjectId('690c1002719d516ba19eb083'), 'course': 'Course 20', 'enrollments': 84, 'department': 'History', 'enrollment_category': 'high'}
# {'_id': ObjectId('690c1002719d516ba19eb084'), 'course': 'Course 21', 'enrollments': 30, 'department': 'Physics', 'enrollment_category': 'high'}
# {'_id': ObjectId('690c1002719d516ba19eb085'), 'course': 'Course 22', 'enrollments': 84, 'department': 'Physics', 'enrollment_category': 'high'}
# {'_id': ObjectId('690c1002719d516ba19eb086'), 'course': 'Course 23', 'enrollments': 50, 'department': 'History', 'enrollment_category': 'high'}
# {'_id': ObjectId('690c1002719d516ba19eb087'), 'course': 'Course 24', 'enrollments': 60, 'department': 'Mathematics', 'enrollment_category': 'high'}
# {'_id': ObjectId('690c1002719d516ba19eb088'), 'course': 'Course 25', 'enrollments': 47, 'department': 'History', 'enrollment_category': 'high'}
# {'_id': ObjectId('690c1002719d516ba19eb089'), 'course': 'Course 26', 'enrollments': 78, 'department': 'Physics', 'enrollment_category': 'high'}
# {'_id': ObjectId('690c1002719d516ba19eb08a'), 'course': 'Course 27', 'enrollments': 35, 'department': 'History', 'enrollment_category': 'high'}
# {'_id': ObjectId('690c1002719d516ba19eb08b'), 'course': 'Course 28', 'enrollments': 99, 'department': 'Computer Science', 'enrollment_category': 'high'}
# {'_id': ObjectId('690c1002719d516ba19eb08c'), 'course': 'Course 29', 'enrollments': 92, 'department': 'History', 'enrollment_category': 'high'}
# {'_id': ObjectId('690c1002719d516ba19eb08d'), 'course': 'Course 30', 'enrollments': 20, 'department': 'Economics', 'enrollment_category': 'low'}
# {'_id': ObjectId('690c1002719d516ba19eb08e'), 'course': 'Course 31', 'enrollments': 21, 'department': 'History', 'enrollment_category': 'high'}
# {'_id': ObjectId('690c1002719d516ba19eb08f'), 'course': 'Course 32', 'enrollments': 95, 'department': 'Computer Science', 'enrollment_category': 'high'}
# {'_id': ObjectId('690c1002719d516ba19eb090'), 'course': 'Course 33', 'enrollments': 46, 'department': 'Mathematics', 'enrollment_category': 'high'}
# {'_id': ObjectId('690c1002719d516ba19eb091'), 'course': 'Course 34', 'enrollments': 40, 'department': 'History', 'enrollment_category': 'high'}
# {'_id': ObjectId('690c1002719d516ba19eb092'), 'course': 'Course 35', 'enrollments': 55, 'department': 'History', 'enrollment_category': 'high'}
# {'_id': ObjectId('690c1002719d516ba19eb093'), 'course': 'Course 36', 'enrollments': 80, 'department': 'Economics', 'enrollment_category': 'high'}
# {'_id': ObjectId('690c1002719d516ba19eb094'), 'course': 'Course 37', 'enrollments': 81, 'department': 'Mathematics', 'enrollment_category': 'high'}
# {'_id': ObjectId('690c1002719d516ba19eb095'), 'course': 'Course 38', 'enrollments': 30, 'department': 'Economics', 'enrollment_category': 'high'}
# {'_id': ObjectId('690c1002719d516ba19eb096'), 'course': 'Course 39', 'enrollments': 95, 'department': 'History', 'enrollment_category': 'high'}
# {'_id': ObjectId('690c1002719d516ba19eb097'), 'course': 'Course 40', 'enrollments': 23, 'department': 'History', 'enrollment_category': 'high'}
# {'_id': ObjectId('690c1002719d516ba19eb098'), 'course': 'Course 41', 'enrollments': 87, 'department': 'History', 'enrollment_category': 'high'}
# {'_id': ObjectId('690c1002719d516ba19eb099'), 'course': 'Course 42', 'enrollments': 31, 'department': 'Physics', 'enrollment_category': 'high'}
# {'_id': ObjectId('690c1002719d516ba19eb09a'), 'course': 'Course 43', 'enrollments': 94, 'department': 'Physics', 'enrollment_category': 'high'}
# {'_id': ObjectId('690c1002719d516ba19eb09b'), 'course': 'Course 44', 'enrollments': 72, 'department': 'Physics', 'enrollment_category': 'high'}
# {'_id': ObjectId('690c1002719d516ba19eb09c'), 'course': 'Course 45', 'enrollments': 81, 'department': 'Computer Science', 'enrollment_category': 'high'}
# {'_id': ObjectId('690c1002719d516ba19eb09d'), 'course': 'Course 46', 'enrollments': 11, 'department': 'Mathematics', 'enrollment_category': 'low'}
# {'_id': ObjectId('690c1002719d516ba19eb09e'), 'course': 'Course 47', 'enrollments': 43, 'department': 'Economics', 'enrollment_category': 'high'}
# {'_id': ObjectId('690c1002719d516ba19eb09f'), 'course': 'Course 48', 'enrollments': 63, 'department': 'History', 'enrollment_category': 'high'}
# {'_id': ObjectId('690c1002719d516ba19eb0a0'), 'course': 'Course 49', 'enrollments': 19, 'department': 'History', 'enrollment_category': 'low'}
# {'_id': ObjectId('690c1002719d516ba19eb0a1'), 'course': 'Course 50', 'enrollments': 56, 'department': 'Mathematics', 'enrollment_category': 'high'}

# %%
# Homework for Students

# Homework 1: Perform an aggregation to get a count of courses per department
# Menghitung jumlah mata kuliah (courses) di setiap department.
pipeline = [{'$group': {'_id': '$department', 'course_count': {'$sum': 1}}}] # menghitung jumlah course per department

print("Jumlah Course (Mata Kuliah) di Setiap Departemen: ")
for result in courses_collection.aggregate(pipeline):
    print(result)
# Out:
# Jumlah Course (Mata Kuliah) di Setiap Departemen:
# {'_id': 'Mathematics', 'course_count': 11}
# {'_id': 'Computer Science', 'course_count': 6}
# {'_id': 'Data Science', 'course_count': 1}
# {'_id': 'Physics', 'course_count': 10}
# {'_id': 'Economics', 'course_count': 6}
# {'_id': 'History', 'course_count': 15}

# %%
# Homework 2: Use $match and $group together to filter and get only courses with enrollments over 25 in 'Computer Science'
# Memfilter data agar hanya menampilkan course di jurusan Computer Science dengan jumlah enrollments > 25, lalu dikelompokkan.

pipeline = [{'$match': {'department': 'Computer Science', 'enrollments': {'$gt': 25}}}, {'$group': {'_id': '$department', 'total_courses': {'$sum': 1}, 'average_enrollment': {'$avg': '$enrollments'}}}]

print("Courses di 'Computer Science' dengan Enrollments > 25: ")
for result in courses_collection.aggregate(pipeline):
    print(result)
# Out:
# Courses di 'Computer Science' dengan Enrollments > 25:
# {'_id': 'Computer Science', 'total_courses': 6, 'average_enrollment': 64.66666666666667}

# %%
# Homework 3: Apply $lookup to join courses collection with students collection based on student enrollments
# Melakukan join antara dua koleksi (courses dan students) berdasarkan relasi student_id.

pipeline = [{'$lookup': {'from': 'students', 'localField': 'student_id', 'foreignField': 'student_id', 'as': 'student_details'}}]

print("Hasil Join antara Koleksi 'courses' dan 'students' berdasarkan student_id: ")
for result in courses_collection.aggregate(pipeline):
    print(result)
# Out:
# Hasil Join antara Koleksi 'courses' dan 'students' berdasarkan student_id:
# {'_id': ObjectId('690c1002719d516ba19eb070'), 'course': 'Course 1', 'enrollments': 50, 'department': 'History', 'student_details': []}
# {'_id': ObjectId('690c1002719d516ba19eb071'), 'course': 'Course 2', 'enrollments': 26, 'department': 'Computer Science', 'student_details': []}
# {'_id': ObjectId('690c1002719d516ba19e